# %% [markdown]
# # Baseline

# %%
! pip install matplotlib

# %%
import matplotlib.pyplot as plt

def generate_latency(array1,array2):
    return [a / b for a, b in zip(array1, array2)]

xlabel = [1, 6, 11, 16, 21, 26, 31, 36, 41, 46, 51, 56, 61, 66, 71, 76, 81, 86, 91, 96]
all_time = [54.558129739761355, 54.55231428146362, 53.47549080848694, 54.67371206283569, 69.20663743019104, 67.52572059631348, 68.21893439292907, 68.02363529205323, 68.03446688652039, 67.85994458198547, 68.6719027519226, 65.99877433776855, 53.99912157058716, 54.71725034713745, 53.674317359924316, 55.15621123313904, 53.509470319747926, 54.73798289299011, 54.02368502616882, 55.318118238449095]
deploy_time = [53.03116908073425, 53.79516739845276, 52.415679693222046, 53.03827161788941, 66.34920887947082, 64.89091439247132, 64.87389421463013, 64.5051739692688, 64.59988441467286, 64.27287712097169, 64.2826542377472, 63.35990982055664, 53.14817681312561, 53.060404539108276, 52.17271347045899, 53.54162282943726, 52.41553692817688, 52.8258451461792, 52.60210132598877, 53.634016847610475]
inference_time = [1.5269606590270997, 0.7571468830108643, 1.0598111152648926, 1.6354404449462892, 2.857428550720215, 2.634806203842163, 3.3450401782989503, 3.518461322784424, 3.434582471847534, 3.587067461013794, 4.389248514175415, 2.638864517211914, 0.8509447574615479, 1.6568458080291748, 1.501603889465332, 1.6145884037017821, 1.093933391571045, 1.912137746810913, 1.4215837001800538, 1.684101390838623]
# 示例数据
x = xlabel
y = generate_latency(inference_time,xlabel)

# 创建折线图
plt.plot(x, y, marker='o')

# 添加标题和标签
#plt.title('Line Chart Example')
plt.xlabel('RPS')
plt.ylabel('Latency (s)')

# 显示图表
plt.show()

# %%
import matplotlib.pyplot as plt

def generate_latency(array1,array2):
    return [a / b for a, b in zip(array1, array2)]

xlabel = [1, 6, 11, 16, 21, 26, 31, 36, 41, 46, 51, 56, 61, 66, 71, 76, 81, 86, 91, 96]
all_time = [54.558129739761355, 54.55231428146362, 53.47549080848694, 54.67371206283569, 69.20663743019104, 67.52572059631348, 68.21893439292907, 68.02363529205323, 68.03446688652039, 67.85994458198547, 68.6719027519226, 65.99877433776855, 53.99912157058716, 54.71725034713745, 53.674317359924316, 55.15621123313904, 53.509470319747926, 54.73798289299011, 54.02368502616882, 55.318118238449095]
deploy_time = [53.03116908073425, 53.79516739845276, 52.415679693222046, 53.03827161788941, 66.34920887947082, 64.89091439247132, 64.87389421463013, 64.5051739692688, 64.59988441467286, 64.27287712097169, 64.2826542377472, 63.35990982055664, 53.14817681312561, 53.060404539108276, 52.17271347045899, 53.54162282943726, 52.41553692817688, 52.8258451461792, 52.60210132598877, 53.634016847610475]
inference_time = [1.5269606590270997, 0.7571468830108643, 1.0598111152648926, 1.6354404449462892, 2.857428550720215, 2.634806203842163, 3.3450401782989503, 3.518461322784424, 3.434582471847534, 3.587067461013794, 4.389248514175415, 2.638864517211914, 0.8509447574615479, 1.6568458080291748, 1.501603889465332, 1.6145884037017821, 1.093933391571045, 1.912137746810913, 1.4215837001800538, 1.684101390838623]
# 示例数据
x = xlabel
y = generate_latency(inference_time,xlabel)

# 创建折线图
plt.plot(x, y, marker='o')

# 添加标题和标签
#plt.title('Line Chart Example')
plt.xlabel('RPS')
plt.ylabel('Latency (s)')

# 显示图表
plt.show()
